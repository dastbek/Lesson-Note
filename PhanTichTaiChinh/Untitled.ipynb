# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test = pd.read_clipboard()

# %%
test=test.astype({'year':'category'})

# %%
test = test.set_index("year")

# %%
plt.style.use("bmh")
g = test.plot(linewidth=2,marker="o",figsize=(15,10))

g
# Out:
# <AxesSubplot:xlabel='year'>

# %%
g.figure.savefig("current.png")

# %%
test2= pd.read_clipboard()

# %%
test2 =test2.set_index("year")

# %%
test2
# Out:
#       Current  Quick   Cash payment Cty
# year
# 2019    2.722   2.003         0.168  HP
# 2020    1.092   0.586         0.264  HP
# 2021    1.282   0.708         0.306  HP
# 2019    0.839   0.320         0.033  HS
# 2020    1.003   0.389         0.064  HS
# 2021    1.298   0.439         0.034  HS

# %%
plt.style.use("bmh")
test2.plot()
# Out:
# <AxesSubplot:xlabel='year'>
